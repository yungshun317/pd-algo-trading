# %% [markdown]
# # 1. Financial Statements
# Only annual & quarterly historical balance sheet data are available on Yahoo.
# ## 1-1. Balance Sheet

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
aapl = yf.Ticker(ticker="AAPL")
aapl
# Out:
# yfinance.Ticker object <AAPL>

# %%
# Annual in million USD
balance_sheet = aapl.get_balance_sheet() / 1000000
balance_sheet
# Out:
#                                            2024-09-30 2023-09-30 2022-09-30  \
# TreasurySharesNumber                              NaN        0.0        NaN
# OrdinarySharesNumber                        15116.786  15550.061  15943.425
# ShareIssued                                 15116.786  15550.061  15943.425
# NetDebt                                       76686.0    81123.0    96423.0
# TotalDebt                                    106629.0   111088.0   132480.0
# ...                                               ...        ...        ...
# CashCashEquivalentsAndShortTermInvestments    65171.0    61555.0    48304.0
# OtherShortTermInvestments                     35228.0    31590.0    24658.0
# CashAndCashEquivalents                        29943.0    29965.0    23646.0
# CashEquivalents                                2744.0     1606.0     5100.0
# CashFinancial                                 27199.0    28359.0    18546.0
#
# ...

# %% [markdown]
# ## 1-2. Income Statement

# %%
# In million USD
income_stmt = aapl.get_income_stmt() / 1000000
income_stmt
# Out:
#                                                    2024-09-30 2023-09-30  \
# TaxEffectOfUnusualItems                                   0.0        0.0
# TaxRateForCalcs                                           0.0        0.0
# NormalizedEBITDA                                     134661.0   125820.0
# NetIncomeFromContinuingOperationNetMinorityInte...    93736.0    96995.0
# ReconciledDepreciation                                11445.0    11519.0
# ReconciledCostOfRevenue                              210352.0   214137.0
# EBITDA                                               134661.0   125820.0
# EBIT                                                 123216.0   114301.0
# NetInterestIncome                                         NaN     -183.0
# InterestExpense                                           NaN     3933.0
# InterestIncome                                            NaN     3750.0
# NormalizedIncome                                      93736.0    96995.0
# ...

# %% [markdown]
# ## 1-3. Cashflow Statement

# %%
# In million USD 
cashflow = aapl.get_cashflow() / 1000000
cashflow
# Out:
#                                           2024-09-30 2023-09-30 2022-09-30  \
# FreeCashFlow                                108807.0    99584.0   111443.0
# RepurchaseOfCapitalStock                    -94949.0   -77550.0   -89402.0
# RepaymentOfDebt                              -9958.0   -11151.0    -9543.0
# IssuanceOfDebt                                   0.0     5228.0     5465.0
# IssuanceOfCapitalStock                           NaN        NaN        NaN
# CapitalExpenditure                           -9447.0   -10959.0   -10708.0
# InterestPaidSupplementalData                     NaN     3803.0     2865.0
# IncomeTaxPaidSupplementalData                26102.0    18679.0    19573.0
# EndCashPosition                              29943.0    30737.0    24977.0
# BeginningCashPosition                        30737.0    24977.0    35929.0
# ChangesInCash                                 -794.0     5760.0   -10952.0
# ...

# %% [markdown]
# ## 1-4. Quarterly Statements

# %%
aapl.quarterly_balance_sheet
# Out:
#                                                       2024-09-30  \
# Treasury Shares Number                                       NaN
# Ordinary Shares Number                             15116786000.0
# Share Issued                                       15116786000.0
# Net Debt                                           76686000000.0
# Total Debt                                        106629000000.0
# ...                                                          ...
# Cash Cash Equivalents And Short Term Investments   65171000000.0
# Other Short Term Investments                       35228000000.0
# Cash And Cash Equivalents                          29943000000.0
# Cash Equivalents                                    2744000000.0
# Cash Financial                                     27199000000.0
#
#                                                       2024-06-30  \
# Treasury Shares Number                                       NaN
# ...

# %%
aapl.quarterly_income_stmt
# Out:
#                                                        2024-09-30  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                           0.21
# Normalized EBITDA                                   32502000000.0
# Net Income From Continuing Operation Net Minori...  14736000000.0
# Reconciled Depreciation                              2911000000.0
# Reconciled Cost Of Revenue                          51051000000.0
# EBITDA                                              32502000000.0
# EBIT                                                29591000000.0
# Net Interest Income                                           NaN
# Interest Expense                                              NaN
# Interest Income                                               NaN
# Normalized Income                                   14736000000.0
# Net Income From Continuing And Discontinued Ope...  14736000000.0
# ...

# %%
aapl.quarterly_cashflow
# Out:
#                                                    2024-09-30     2024-06-30  \
# Free Cash Flow                                  23903000000.0  26707000000.0
# Repurchase Of Capital Stock                    -25083000000.0 -26522000000.0
# Repayment Of Debt                                 427000000.0  -3253000000.0
# Issuance Of Debt                                          0.0            NaN
# Capital Expenditure                             -2908000000.0  -2151000000.0
# Interest Paid Supplemental Data                           NaN            NaN
# Income Tax Paid Supplemental Data                6872000000.0   4699000000.0
# End Cash Position                               29943000000.0  26635000000.0
# Beginning Cash Position                         26635000000.0  33921000000.0
# Changes In Cash                                  3308000000.0  -7286000000.0
# Financing Cash Flow                            -24948000000.0 -36017000000.0
# ...
